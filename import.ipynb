# %%
# !pip install psycopg2-binary sqlalchemy pandas skyfield
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 23.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 24.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --------------------------- ------------ 7.6/11.0 MB 38.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 22.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 18.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
# ...

# %%
import psycopg2
from sqlalchemy import create_engine

# Connection string
DATABASE_URL = "postgresql://postgres:your_secure_password_here@localhost:5432/planetary_ml"

# Create engine
engine = create_engine(DATABASE_URL)

# Test connection
with engine.connect() as conn:
    result = conn.execute("SELECT version()")
    print(result.fetchone())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File d:\Astro_Finance\venv\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1414 try:
# -> 1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[7], line 12
#      10 # Test connection
#      11 with engine.connect() as conn:
# ---> 12     result = conn.execute("SELECT version()")
#      13     print(result.fetchone())
#
# File d:\Astro_Finance\venv\Lib\site-packages\sqlalchemy\engine\base.py:1417, in Connection.execute(self, statement, parameters, execution_options)
# ...

# %%
docker run --name timescaledb -e POSTGRES_PASSWORD=pwd \
  -d timescale/timescaledb:latest-pg15
# Out:
#   Cell In[5], line 1
#     docker run --name timescaledb -e POSTGRES_PASSWORD=pwd \
#            ^
# SyntaxError: invalid syntax

# %%
from skyfield import api
ts = api.load.timescale()
eph = api.load('de421.bsp')
